# %% [markdown]
# # Project: Continuous Control
# ---
# In this notebook, you will implement an actor-critic agent to solve Unity Environment's Reacher environment.

# %% [markdown]
# ### 1. Import necessary packages
# 1. We import some basic libraries such as Numpy, torch,copy, datetime, namedtuple, deque, and matplotlib.
# 1. We import Pytorch libraries for neural networks.
# 1. We import UnityEnvironment that will allow us to interact with the Banana Environment.
# 1. We define a device variable that operates the code on GPU if GPU is available.

# %%
import random
import torch
import numpy as np
import copy
import datetime
from collections import namedtuple, deque

import matplotlib.pyplot as plt
# %matplotlib inline
plt.ion()

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from unityagents import UnityEnvironment

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### 2. Instantiate the Environment
# Next, we will start the environment!  **_Before running the code cell below_**, change the `Environment_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# Environment_name = "Reacher.exe"
# ```

# %%
Environment_name = "Reacher_20_Windows_x86_64\Reacher.exe"
env = UnityEnvironment(file_name=Environment_name)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]
print(brain_name)
print(brain)
# Out:
# ReacherBrain
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# ### 3. Explore the Environment
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 4. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
tmax = 20
for _ in range(tmax):
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.0

# %% [markdown]
# ### 5. Build Our Actor and Critic Networks
#
# The Neural Network models we are going to use consist of fully connected layers only as the state space is not pixels.

# %%
def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

class Actor(nn.Module):
    """Actor (Policy) Model."""

    def __init__(self, state_size, action_size, seed, fc1_units=400, fc2_units=300):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)
        self.reset_parameters()

    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state):
        """Build an actor (policy) network that maps states -> actions."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return torch.tanh(self.fc3(x))


class Critic(nn.Module):
    """Critic (Value) Model."""

    def __init__(self, state_size, action_size, seed, fcs1_units=400, fc2_units=300):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fcs1_units (int): Number of nodes in the first hidden layer
            fc2_units (int): Number of nodes in the second hidden layer
        """
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fcs1 = nn.Linear(state_size, fcs1_units)
        self.fc2 = nn.Linear(fcs1_units+action_size, fc2_units)
        self.fc3 = nn.Linear(fc2_units, 1)
        self.reset_parameters()

    def reset_parameters(self):
        self.fcs1.weight.data.uniform_(*hidden_init(self.fcs1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)

    def forward(self, state, action):
        """Build a critic (value) network that maps (state, action) pairs -> Q-values."""
        xs = F.relu(self.fcs1(state))
        x = torch.cat((xs, action), dim=1)
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# ### 6. Build Our Actor-Critic Agent
#
# We define a class called `ReplayBuffer` that holds the memory of past experiences.

# %%
class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# We define a class called `OUNoise` that creates a sample of Ornstein-Uhlenbeck noise process that will be added on actions to provide exploration.

# %%
class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.15, sigma=0.2):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.random.standard_normal(len(x))
        self.state = x + dx
        return self.state

# %% [markdown]
# - The agent will use the actor and critic models we built to make 2 identical Neural Networks of each:
#     1. Local actor Neural Network: This will be updated every epoch
#     1. Target actor Neural Network: This will be soft-updated with the value of the local neural network
#     1. Local critic Neural Network: This will be updated every epoch
#     1. Target critic Neural Network: This will be soft-updated with the value of the local neural network
#
#
# - The hyper parameters in the agent will be:
#     1. `BUFFER_SIZE` - Size of the pool of past experiences the agent will choose from
#     1. `BATCH_SIZE` - Minibatch size
#     1. `GAMMA` - Discount factor &gamma;
#     1. `TAU` - Soft updae parameter &tau;
#     1. `LR_ACTOR` - Learning rate parameter for the actor network
#     1. `LR_CRITIC` - Learning rate parameter for the critic network
#     1. `WEIGHT_DECAY` - L2 weight decay
#     1. `LEARN_UPDATES` - Number of learning updates
#     1. `TIME_STEPS_TO_LEARN` - Every n time steps do update

# %%
BUFFER_SIZE = int(1e6)  # replay buffer size
BATCH_SIZE = 128        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-4         # learning rate of the actor 
LR_CRITIC = 1e-4        # learning rate of the critic
WEIGHT_DECAY = 0        # L2 weight decay

LEARN_UPDATES = 10          # number of learning updates
TIME_STEPS_TO_LEARN = 20    # every n time step do update

class Agent():
    """Interacts with and learns from the environment."""
    
    def __init__(self, state_size, action_size, random_seed):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            random_seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(random_seed)

        # Actor Network (w/ Target Network)
        self.actor_local = Actor(state_size, action_size, random_seed).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed).to(device)
        self.actor_optimizer = optim.Adam(self.actor_local.parameters(), lr=LR_ACTOR)

        # Critic Network (w/ Target Network)
        self.critic_local = Critic(state_size, action_size, random_seed).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed).to(device)
        self.critic_optimizer = optim.Adam(self.critic_local.parameters(), lr=LR_CRITIC, weight_decay=WEIGHT_DECAY)

        # Noise process
        self.noise = OUNoise(action_size, random_seed)

        # Replay memory
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, random_seed)
    
    def step(self, time_step, state, action, reward, next_state, done):
        """Save experience in replay memory, and use random sample from buffer to learn."""
        # Save experience / reward
        self.memory.add(state, action, reward, next_state, done)

        # only learn every n_time_steps
        if time_step % TIME_STEPS_TO_LEARN != 0:
            return
        
        # Learn, if enough samples are available in memory
        if len(self.memory) > BATCH_SIZE:
            for _ in range(LEARN_UPDATES):
                experiences = self.memory.sample()
                self.learn(experiences, GAMMA)

    def act(self, state, add_noise=True):
        """Returns actions for given state as per current policy."""
        state = torch.from_numpy(state).float().unsqueeze(0).to(device) #typecast to torch.Tensor
        self.actor_local.eval()
        with torch.no_grad():
            action = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()
        if add_noise:
            action += self.noise.sample()
        return np.clip(action, -1, 1)

    def reset(self):
        self.noise.reset()

    def learn(self, experiences, gamma):
        """Update policy and value parameters using given batch of experience tuples.
        Q_targets = r + γ * critic_target(next_state, actor_target(next_state))
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value

        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # ---------------------------- update critic ---------------------------- #
        # Get predicted next-state actions and Q values from target models
        actions_next = self.actor_target(next_states)
        Q_targets_next = self.critic_target(next_states, actions_next)
        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))
        
        # Compute critic loss
        Q_expected = self.critic_local(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)
        
        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        nn.utils.clip_grad_norm_(self.critic_local.parameters(), 1) #clip gradients
        self.critic_optimizer.step()

        # ---------------------------- update actor ---------------------------- #
        # Compute actor loss
        actions_pred = self.actor_local(states)
        actor_loss = -self.critic_local(states, actions_pred).mean()
        
        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # ----------------------- update target networks ----------------------- #
        self.soft_update(self.critic_local, self.critic_target, TAU)
        self.soft_update(self.actor_local, self.actor_target, TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

# %% [markdown]
# ### 7. Train Many Agents
# First, we will start the environment!  **_Before running the code cell below_**, change the `Environment_name` parameter to match the location of the Unity environment that you downloaded. Make sure it's the Reacher with 20 agents.

# %% [markdown]
# Define a function `actor_critic_train_many` that trains any number of agents.
#
# __Note:__ the reward was modified so that it is `0.1` if the agent is touching the target and `0` if it's not. The original reward gives a very small reward, nearly `0.003`, which is very small so the agent didn't learn anything.

# %%
def actor_critic_train_many(env, agents, scores, n_episodes=2000, max_t=1000, add_noise=True, max_score=30):
    """Deep Q-Learning.
    
    Params
    ======
        env (Environment_variable) : an instance of the enivronment class
        agents (list) : a list containing instances of the agent class
        scores (list) : an empty list to hold the scores
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        add_noise (boolean): whether or not provide noise for exploration
        max_score (int): the maximum average reward over 100 episodes at which the training stops
    """
    scores_window = deque(maxlen=100)  # last 100 scores
    brain_name = env.brain_names[0]
    num_agents = len(agents)
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]  # reset the environment
        states = env_info.vector_observations              # get the current state
        
        for agent in agents:                               # Reset Noise
            agent.reset()                                  
        
        scores_one_episode = np.zeros(num_agents)
        for t in range(max_t):
            actions = np.array([agents[i].act(states[i]) for i in range(num_agents)]).squeeze(1) # choose the apropriate action
            env_info = env.step(actions)[brain_name]        # send the action to the environment
            next_states = env_info.vector_observations      # get the next state
            rewards = np.array([0.1 if env_info.rewards[i] > 0 else 0.0 for i in range(num_agents)]) # get the reward
            dones = env_info.local_done                 # see if episode has finished
            
            for i in range(num_agents):
                agents[i].step(t, states[i], actions[i], rewards[i], next_states[i], dones[i])
            
            states = next_states
            scores_one_episode += rewards
            print('\rTimestep {}\tAvg.Score {:.2f}'.format(t, np.mean(scores_one_episode)), end="")
            if np.any(dones):
                break
        
        score = np.mean(scores_one_episode)             # average score over agents in one episode
        scores_window.append(score)                     # save most recent score
        scores_window_mean = np.mean(scores_window)     # average score over last 100 episodes
        scores.append(score)                            # save most recent score
        print('\rEpisode {}\tScore {:.2f}\tAverage Score: {:.2f}'.format(i_episode, score, scores_window_mean))
        if i_episode % 100 == 0:
            print('\rEpisode {}\tScore {:.2f}\tAverage Score: {:.2f}'.format(i_episode, score, scores_window_mean))
        if i_episode % 100 == 0:
            for i in range(num_agents):
                torch.save(agents[i].actor_local.state_dict(), "checkpoint_actor_{}.pth".format(i))
                torch.save(agents[i].critic_local.state_dict(), "checkpoint_critic_{}.pth".format(i))
        if np.mean(scores_window)>=max_score:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode, scores_window_mean))
            for i in range(num_agents):
                torch.save(agents[i].actor_local.state_dict(), "checkpoint_actor_{}.pth".format(i))
                torch.save(agents[i].critic_local.state_dict(), "checkpoint_critic_{}.pth".format(i))
            break

# %% [markdown]
# Run the cell below to begin training

# %%
# Choose default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# Determine state and action sizes
env_info = env.reset(train_mode=True)[brain_name]
state_size = len(env_info.vector_observations[0])
action_size = brain.vector_action_space_size
num_agents = len(env_info.agents)

# Instatiate the agents
agents = []
for _ in range(num_agents):
    agents.append(Agent(state_size=state_size, action_size=action_size, random_seed=1234))

# Define training parameters
n_episodes=500         # maximum number of training episodes
max_t=int(1000)        # maximum number of timesteps per episode
add_noise=True         # whether or not provide noise for exploration
max_score=50           # the maximum average reward over 100 episodes at which the training stops

# Begin training
scores = []
actor_critic_train_many(env, agents, scores, n_episodes=n_episodes, max_t=max_t, add_noise=add_noise, max_score=max_score)
# Out:
# Episode 1	Score 1.64	Average Score: 1.64
# Episode 2	Score 1.35	Average Score: 1.50
# Episode 3	Score 2.01	Average Score: 1.67
# Episode 4	Score 2.20	Average Score: 1.80
# Episode 5	Score 1.89	Average Score: 1.82
# Episode 6	Score 2.08	Average Score: 1.86
# Episode 7	Score 2.30	Average Score: 1.92
# Episode 8	Score 2.54	Average Score: 2.00
# Episode 9	Score 1.96	Average Score: 2.00
# Episode 10	Score 3.72	Average Score: 2.17
# Episode 11	Score 2.68	Average Score: 2.22
# Episode 12	Score 2.83	Average Score: 2.27
# Episode 13	Score 2.73	Average Score: 2.30
# Episode 14	Score 2.73	Average Score: 2.33
# Episode 15	Score 2.43	Average Score: 2.34
# Episode 16	Score 3.36	Average Score: 2.40
# Episode 17	Score 4.27	Average Score: 2.51
# Episode 18	Score 3.79	Average Score: 2.58
# Episode 19	Score 3.49	Average Score: 2.63
# Episode 20	Score 3.59	Average Score: 2.68
# Episode 21	Score 3.68	Average Score: 2.73
# Episode 22	Score 3.10	Average Score: 2.74
# Episode 23	Score 4.06	Average Score: 2.80
# Episode 24	Score 4.23	Average Score: 2.86
# Episode 25	Score 4.64	Average Score: 2.93
# Episode 26	Score 4.71	Average Score: 3.00
# Episode 27	Score 5.50	Average Score: 3.09
# Episode 28	Score 3.62	Average Score: 3.11
# Episode 29	Score 4.65	Average Score: 3.17
# Episode 30	Score 4.97	Average Score: 3.23
# Episode 31	Score 5.74	Average Score: 3.31
# Episode 32	Score 5.95	Average Score: 3.39
# Episode 33	Score 7.02	Average Score: 3.50
# Episode 34	Score 6.25	Average Score: 3.58
# Episode 35	Score 6.79	Average Score: 3.67
# Episode 36	Score 7.01	Average Score: 3.77
# Episode 37	Score 6.61	Average Score: 3.84
# Episode 38	Score 6.80	Average Score: 3.92
# Episode 39	Score 7.05	Average Score: 4.00
# Episode 40	Score 7.04	Average Score: 4.08
# Episode 41	Score 8.12	Average Score: 4.18
# Episode 42	Score 6.99	Average Score: 4.24
# Episode 43	Score 8.37	Average Score: 4.34
# Episode 44	Score 8.02	Average Score: 4.42
# Episode 45	Score 8.75	Average Score: 4.52
# Episode 46	Score 8.32	Average Score: 4.60
# Episode 47	Score 8.81	Average Score: 4.69
# Episode 48	Score 9.36	Average Score: 4.79
# Episode 49	Score 10.58	Average Score: 4.91
# Episode 50	Score 11.48	Average Score: 5.04
# Episode 51	Score 9.76	Average Score: 5.13
# Episode 52	Score 10.29	Average Score: 5.23
# Episode 53	Score 10.05	Average Score: 5.32
# Episode 54	Score 11.24	Average Score: 5.43
# Episode 55	Score 10.81	Average Score: 5.53
# Episode 56	Score 11.94	Average Score: 5.64
# Episode 57	Score 12.59	Average Score: 5.76
# Episode 58	Score 11.51	Average Score: 5.86
# Episode 59	Score 14.03	Average Score: 6.00
# Episode 60	Score 14.56	Average Score: 6.15
# Episode 61	Score 13.05	Average Score: 6.26
# Episode 62	Score 13.32	Average Score: 6.37
# Episode 63	Score 14.99	Average Score: 6.51
# Episode 64	Score 13.68	Average Score: 6.62
# Episode 65	Score 15.89	Average Score: 6.76
# Episode 66	Score 14.73	Average Score: 6.88
# Episode 67	Score 16.91	Average Score: 7.03
# Episode 68	Score 14.90	Average Score: 7.15
# Episode 69	Score 16.98	Average Score: 7.29
# Episode 70	Score 16.52	Average Score: 7.42
# Episode 71	Score 17.16	Average Score: 7.56
# Episode 72	Score 16.02	Average Score: 7.68
# Episode 73	Score 17.07	Average Score: 7.81
# Episode 74	Score 16.74	Average Score: 7.93
# Episode 75	Score 18.77	Average Score: 8.07
# Episode 76	Score 17.03	Average Score: 8.19
# Episode 77	Score 19.61	Average Score: 8.34
# Episode 78	Score 17.97	Average Score: 8.46
# Episode 79	Score 18.21	Average Score: 8.59
# Episode 80	Score 19.11	Average Score: 8.72
# Episode 81	Score 19.36	Average Score: 8.85
# Episode 82	Score 19.24	Average Score: 8.98
# Episode 83	Score 19.15	Average Score: 9.10
# Episode 84	Score 21.26	Average Score: 9.24
# Episode 85	Score 20.41	Average Score: 9.37
# Episode 86	Score 22.62	Average Score: 9.53
# Episode 87	Score 20.48	Average Score: 9.65
# Episode 88	Score 21.45	Average Score: 9.79
# Episode 89	Score 25.42	Average Score: 9.96
# Episode 90	Score 21.95	Average Score: 10.10
# Episode 91	Score 25.05	Average Score: 10.26
# Episode 92	Score 23.78	Average Score: 10.41
# Episode 93	Score 24.23	Average Score: 10.56
# Episode 94	Score 25.67	Average Score: 10.72
# Episode 95	Score 24.19	Average Score: 10.86
# Episode 96	Score 24.38	Average Score: 11.00
# Episode 97	Score 24.68	Average Score: 11.14
# Episode 98	Score 24.08	Average Score: 11.27
# Episode 99	Score 26.74	Average Score: 11.43
# Episode 100	Score 27.69	Average Score: 11.59
# Episode 100	Score 27.69	Average Score: 11.59
# Episode 101	Score 28.51	Average Score: 11.86
# Episode 102	Score 26.52	Average Score: 12.11
# Episode 103	Score 24.72	Average Score: 12.34
# Episode 104	Score 28.77	Average Score: 12.60
# Episode 105	Score 32.11	Average Score: 12.91
# Episode 106	Score 27.23	Average Score: 13.16
# Episode 107	Score 29.81	Average Score: 13.43
# Episode 108	Score 32.76	Average Score: 13.74
# Episode 109	Score 29.79	Average Score: 14.01
# Episode 110	Score 29.11	Average Score: 14.27
# Episode 111	Score 34.62	Average Score: 14.59
# Episode 112	Score 31.43	Average Score: 14.87
# Episode 113	Score 30.96	Average Score: 15.16
# Episode 114	Score 35.83	Average Score: 15.49
# Episode 115	Score 31.72	Average Score: 15.78
# Episode 116	Score 36.34	Average Score: 16.11
# Episode 117	Score 33.20	Average Score: 16.40
# Episode 118	Score 34.93	Average Score: 16.71
# Episode 119	Score 35.91	Average Score: 17.03
# Episode 120	Score 34.81	Average Score: 17.35
# Episode 121	Score 35.96	Average Score: 17.67
# Episode 122	Score 39.34	Average Score: 18.03
# Episode 123	Score 39.22	Average Score: 18.38
# Episode 124	Score 38.94	Average Score: 18.73
# Episode 125	Score 38.82	Average Score: 19.07
# Episode 126	Score 35.16	Average Score: 19.38
# Episode 127	Score 38.68	Average Score: 19.71
# Episode 128	Score 40.60	Average Score: 20.08
# Episode 129	Score 38.72	Average Score: 20.42
# Episode 130	Score 46.58	Average Score: 20.83
# Episode 131	Score 41.00	Average Score: 21.19
# Episode 132	Score 47.50	Average Score: 21.60
# Episode 133	Score 40.35	Average Score: 21.94
# Episode 134	Score 46.07	Average Score: 22.33
# Episode 135	Score 41.77	Average Score: 22.68
# Episode 136	Score 42.05	Average Score: 23.03
# Episode 137	Score 44.01	Average Score: 23.41
# Episode 138	Score 43.87	Average Score: 23.78
# Episode 139	Score 43.45	Average Score: 24.14
# Episode 140	Score 43.01	Average Score: 24.50
# Episode 141	Score 45.07	Average Score: 24.87
# Episode 142	Score 45.59	Average Score: 25.26
# Episode 143	Score 44.42	Average Score: 25.62
# Episode 144	Score 45.10	Average Score: 25.99
# Episode 145	Score 44.16	Average Score: 26.34
# Episode 146	Score 47.17	Average Score: 26.73
# Episode 147	Score 47.36	Average Score: 27.12
# Episode 148	Score 49.17	Average Score: 27.51
# Episode 149	Score 50.72	Average Score: 27.92
# Episode 150	Score 44.00	Average Score: 28.24
# Episode 151	Score 48.14	Average Score: 28.62
# Episode 152	Score 46.40	Average Score: 28.99
# Episode 153	Score 49.23	Average Score: 29.38
# Episode 154	Score 50.66	Average Score: 29.77
# Episode 155	Score 48.67	Average Score: 30.15
# Episode 156	Score 49.55	Average Score: 30.53
# Episode 157	Score 48.62	Average Score: 30.89
# Episode 158	Score 51.56	Average Score: 31.29
# Episode 159	Score 50.28	Average Score: 31.65
# Episode 160	Score 50.86	Average Score: 32.01
# Episode 161	Score 49.96	Average Score: 32.38
# Episode 162	Score 51.48	Average Score: 32.76
# Episode 163	Score 54.22	Average Score: 33.16
# Episode 164	Score 52.38	Average Score: 33.54
# Episode 165	Score 56.78	Average Score: 33.95
# Episode 166	Score 55.93	Average Score: 34.36
# Episode 167	Score 56.39	Average Score: 34.76
# Episode 168	Score 54.00	Average Score: 35.15
# Episode 169	Score 57.26	Average Score: 35.55
# Episode 170	Score 55.67	Average Score: 35.94
# Episode 171	Score 56.63	Average Score: 36.34
# Episode 172	Score 56.83	Average Score: 36.75
# Episode 173	Score 59.40	Average Score: 37.17
# Episode 174	Score 58.41	Average Score: 37.59
# Episode 175	Score 55.60	Average Score: 37.95
# Episode 176	Score 56.31	Average Score: 38.35
# Episode 177	Score 61.05	Average Score: 38.76
# Episode 178	Score 58.61	Average Score: 39.17
# Episode 179	Score 56.32	Average Score: 39.55
# Episode 180	Score 56.82	Average Score: 39.93
# Episode 181	Score 60.49	Average Score: 40.34
# Episode 182	Score 61.43	Average Score: 40.76
# Episode 183	Score 58.81	Average Score: 41.16
# Episode 184	Score 62.95	Average Score: 41.57
# Episode 185	Score 60.69	Average Score: 41.98
# Episode 186	Score 59.96	Average Score: 42.35
# Episode 187	Score 61.48	Average Score: 42.76
# Episode 188	Score 60.42	Average Score: 43.15
# Episode 189	Score 53.88	Average Score: 43.43
# Episode 190	Score 60.54	Average Score: 43.82
# Episode 191	Score 62.88	Average Score: 44.20
# Episode 192	Score 60.82	Average Score: 44.57
# Episode 193	Score 60.85	Average Score: 44.93
# Episode 194	Score 63.15	Average Score: 45.31
# Episode 195	Score 65.86	Average Score: 45.73
# Episode 196	Score 61.00	Average Score: 46.09
# Episode 197	Score 63.64	Average Score: 46.48
# Episode 198	Score 63.28	Average Score: 46.87
# Episode 199	Score 66.28	Average Score: 47.27
# Episode 200	Score 65.92	Average Score: 47.65
# Episode 200	Score 65.92	Average Score: 47.65
# Episode 201	Score 65.10	Average Score: 48.02
# Episode 202	Score 65.59	Average Score: 48.41
# Episode 203	Score 63.27	Average Score: 48.79
# Episode 204	Score 65.48	Average Score: 49.16
# Episode 205	Score 66.94	Average Score: 49.51
# Episode 206	Score 63.22	Average Score: 49.87
# Episode 207	Score 66.00	Average Score: 50.23
#
# Environment solved in 207 episodes!	Average Score: 50.23

# %% [markdown]
# Run the cell below to plot the scores:

# %%
# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %% [markdown]
# ### 8. Watch Smart Agents!
#
# In the next code cell, you will load the trained weights from file to watch a smart agent!
# There are 2 weights files: `checkpoint_actor_{}.pth` and `checkpoint_critic_{}.pth` where `{}` is the number of the agent. Copy the name of the file holding the weights into the `torch.load()` first argument of both the actor and the critic.

# %%
# Choose default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# Determine state and action sizes
env_info = env.reset(train_mode=True)[brain_name]
state_size = len(env_info.vector_observations[0])
action_size = brain.vector_action_space_size
num_agents = len(env_info.agents)

# Instatiate the agents
agents = []
for _ in range(num_agents):
    agents.append(Agent(state_size=state_size, action_size=action_size, random_seed=1234))
    
# load the weights from file
if torch.cuda.is_available():
    map_location=lambda storage, loc: storage.cuda()
else:
    map_location='cpu'
for i in range(num_agents):
    agents[i].actor_local.load_state_dict(torch.load("checkpoint_actor_{}.pth".format(i), map_location=map_location))
    agents[i].critic_local.load_state_dict(torch.load("checkpoint_critic_{}.pth".format(i), map_location=map_location))

max_episodes = 10
max_time = 1000
score_board = []

for i_episode in range(1, max_episodes+1):
    env_info = env.reset(train_mode=True)[brain_name]  # reset the environment
    states = env_info.vector_observations              # get the current state
        
    for agent in agents:                               # Reset Noise
        agent.reset()                                  
        
    scores_one_episode = np.zeros(num_agents)
    for t in range(max_t):
        actions = np.array([agents[i].act(states[i]) for i in range(num_agents)]).squeeze(1) # choose the apropriate action
        env_info = env.step(actions)[brain_name]        # send the action to the environment
        next_states = env_info.vector_observations      # get the next state
        rewards = np.array([0.1 if env_info.rewards[i] > 0 else 0.0 for i in range(num_agents)]) # get the reward
        dones = env_info.local_done                 # see if episode has finished
        states = next_states
        scores_one_episode += rewards
        if np.any(dones):
            break
        
    score = np.mean(scores_one_episode)             # average score over agents in one episode
    print("Episode {}\tScore: {}".format(i_episode, score))
    score_board.append(score)
print("Score Average = {}".format(np.mean(score_board)))
# Out:
# Episode 1	Score: 65.25500000000001
# Episode 2	Score: 64.82000000000006
# Episode 3	Score: 66.44500000000002
# Episode 4	Score: 65.41500000000009
# Episode 5	Score: 68.85500000000003
# Episode 6	Score: 64.46000000000005
# Episode 7	Score: 67.92999999999999
# Episode 8	Score: 68.61999999999996
# Episode 9	Score: 68.70499999999998
# Episode 10	Score: 65.81500000000011
# Score Average = 66.63200000000002

# %% [markdown]
# Close the environment.

# %%
env.close()
